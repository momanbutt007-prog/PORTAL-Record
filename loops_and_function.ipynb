# %% [markdown]
# ========================
# ### LOOPS AND FUNCTIONS
# ========================

# %%
# PROGRAM 1: Data Types

def data_types():
    
    age = 25
    cgpa = 3.36
    name = "Momin Butt"
    is_enrolled = True
    student_id = 10
    percentage = 80.5
    department = "Computer Science"
    has_scholarship = False

    subjects = ["Python", "Data Structures", "Algorithms"]
    marks = [85, 90, 88]
    grades = ('A', 'B+', 'A-')
    student_info = {"name": name,"age": age,"cgpa": cgpa,"subjects": subjects}
    
    # Print all
    print("Student Name:", name)
    print("Age:", age)
    print("CGPA:", cgpa)
    print("Enrolled:", is_enrolled)
    print("Subjects:", subjects)
    print("Grades:", grades)
    print("Student Info:", student_info)

data_types()
# Out:
# Student Name: Momin Butt
# Age: 25
# CGPA: 3.36
# Enrolled: True
# Subjects: ['Python', 'Data Structures', 'Algorithms']
# Grades: ('A', 'B+', 'A-')
# Student Info: {'name': 'Momin Butt', 'age': 25, 'cgpa': 3.36, 'subjects': ['Python', 'Data Structures', 'Algorithms']}

# %% [markdown]
# ### OPERATORS (Arithmetic, Comparison, Logical)

# %%
# PROGRAM 2: Operators Demonstration

def operators():
    
    # Arithmetic Operators
    a, b = 15, 4
    print("Addition:", a+b)
    print("Subtraction:", a - b)
    print("Multiplication:", a * b)
    print("Division:", a / b)
    print("Floor Division:", a // b)
    print("Modulus:", a % b)
    print("Exponentiation:", a ** b)
    
    print("============================================")
    # Comparison Operators
    print("Equal to:", a == b)
    print(f"Not equal to:", a != b)
    print(f"Greater than:", a > b)
    print(f"Less than:", a < b)
    print(f"Greater than or equal:", a >= b)
    print(f"Less than or equal:", a <= b)
    
    print("============================================")
    # Logical Operators
    p, q = True, False
    print("AND (p and q):", p and q)
    print("OR (p or q):", p or q)
    print("NOT (not p):", not p)
    
    print("============================================")
    # Assignment Operators
    num = 10
    print("Initial value: {num}")
    num += 5; print("After +=5:", num)
    num -= 3; print("After -=3:", num)
    num *= 2; print("After *=2:", num)
    num /= 4; print("After /=4:", num)

operators()
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625
# ...
# Equal to: False
# Not equal to: True
# Greater than: True
# Less than: False
# Greater than or equal: True
# Less than or equal: False
# ...
# AND (p and q): False
# OR (p or q): True
# NOT (not p): False
# ...
# Initial value: {num}
# After +=5: 15
# After -=3: 12
# After *=2: 24
# After /=4: 6.0

# %% [markdown]
# ### CONDITIONAL STATEMENTS (if-elif-else)

# %%
"""
PROGRAM 3: Conditional Statements
"""
def conditional_statements():
    print("\n" + "="*60)
    print("PROGRAM 3: CONDITIONAL STATEMENTS")
    print("="*60)
    
    
conditional_statements()
    
#check Grade
num=int(input("enter your marks"))
if num>=90:
    print("You got A+ Grade")
elif num>=80: 
    print("You got A Grade")
elif num>= 70:     
    print("You Got B Grade ")
elif num>=60:
    print("You Got C Grade ")
elif num>=50:
    print("You Got D Grade ")
else: 
    print("You Got F Grade ")
    
    # Even/Odd Check
x =int(input("enter the number"))
if x>=1:
    print("number is positive")
else:
    print("number is negative")   
    
#vote rights
age=input("enter your age")
age=int(age)
if age>=18:
     print(f"you are {age} old  eligible to vote")
else:
    print(f"you are {age} old not eligible to vote")
# Out:
# ...
# PROGRAM 3: CONDITIONAL STATEMENTS
# ...
# You got A+ Grade
# number is positive
# you are 26 old  eligible to vote

# %% [markdown]
# #  LOOPS (for and while)

# %%
# PROGRAM 5: Functions

# Basic Function
def greet(name):
    return f"Hello, {name}! Welcome to Python programming."

# Function with multiple parameters
def calculate_area(length, width):
    return length * width

# Function with default parameter
def power(base, exponent=2):
    return base ** exponent

# Function with variable arguments
def sum_all(*numbers):
    return sum(numbers)

# Recursive function
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n - 1)

# Lambda function
square = lambda x: x ** 2

# Function returning multiple values
def get_student_info():
    name = "Alice"
    age = 22
    grade = "A"
    return name, age, grade

def demonstrate_functions():
    # Call basic function
    print(greet("Nomi"))
    
    # Call function with parameters
    area = calculate_area(5, 4)
    print(f"Area of rectangle 5*4: {area}")
    
    # Call function with default parameter
    print(f"2^2 (default): {power(2)}")
    print(f"2^3 (custom): {power(2, 3)}")
    print("============================================")
    # Variable arguments
    result = sum_all(1, 2, 3, 4, 5)
    print(f"Sum of 1,2,3,4,5: {result}")
    
    # Recursive function
    num = 5
    print(f"Factorial of {num}: {factorial(num)}")
    
    print("============================================")
    # Lambda function
    numbers = [1, 2, 3, 4, 5]
    squares = list(map(lambda x: x**2, numbers))
    print(f"Original: {numbers}")
    print(f"Squares: {squares}")
    
    print("============================================")
    # Multiple return values
    name, age, grade = get_student_info()
    print(f"Name: {name}, Age: {age}, Grade: {grade}")
    
    print("============================================")
    # Function documentation
    print(f"greet function doc: {greet.__doc__}")
    print(f"calculate_area doc: {calculate_area.__doc__}")

demonstrate_functions()
# Out:
# 1
# Sum of first 10 numbers: 55
#
# Multiplication Table of 5:
# 5 × 1 = 5
# 5 × 2 = 10
# 5 × 3 = 15
# 5 × 4 = 20
# 5 × 5 = 25
# 5 × 6 = 30
# 5 × 7 = 35
# 5 × 8 = 40
# 5 × 9 = 45
# 5 × 10 = 50
#
# Iterating through list:
# I like Apple
# I like Banana
# I like Orange
# I like Mango
# I like Grapes
#
# 2. WHILE LOOP EXAMPLES:
# Countdown:
# 5
# 4
# 3
# 2
# 1
# Blast Off!
#
# Enter numbers to sum (negative to stop):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 54
#      52 while num >= 0:
#      53     total += num
# ---> 54     num = int(input("Enter number: "))
#      55 print(f"Sum of positive numbers: {total}")
#      57 # Example 3: Factorial
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### FUNCTIONS

# %%
# PROGRAM 5: Functions

# Basic Function
def greet(name):
    return f"Hello, {name}! Welcome to Python programming."

# Function with multiple parameters
def calculate_area(length, width):
    return length * width

# Function with default parameter
def power(base, exponent=2):
    return base ** exponent

# Function with variable arguments
def sum_all(*numbers):
    return sum(numbers)

# Recursive function
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n - 1)

# Lambda function
square = lambda x: x ** 2

# Function returning multiple values
def get_student_info():
    name = "Alice"
    age = 22
    grade = "A"
    return name, age, grade

def demonstrate_functions():
    # Call basic function
    print(greet("Butt Saab"))
    
    # Call function with parameters
    area = calculate_area(5, 4)
    print(f"Area of rectangle 5*4: {area}")
    
    # Call function with default parameter
    print(f"2^2 (default): {power(2)}")
    print(f"2^3 (custom): {power(2, 3)}")
    print("============================================")
    # Variable arguments
    result = sum_all(1, 2, 3, 4, 5)
    print(f"Sum of 1,2,3,4,5: {result}")
    
    # Recursive function
    num = 5
    print(f"Factorial of {num}: {factorial(num)}")
    
    print("============================================")
    # Lambda function
    numbers = [1, 2, 3, 4, 5]
    squares = list(map(lambda x: x**2, numbers))
    print(f"Original: {numbers}")
    print(f"Squares: {squares}")
    
    print("============================================")
    # Multiple return values
    name, age, grade = get_student_info()
    print(f"Name: {name}, Age: {age}, Grade: {grade}")
    
    print("============================================")
    # Function documentation
    print(f"greet function doc: {greet.__doc__}")
    print(f"calculate_area doc: {calculate_area.__doc__}")

demonstrate_functions()
# Out:
# Hello, Butt Saab! Welcome to Python programming.
# Area of rectangle 5*4: 20
# 2^2 (default): 4
# 2^3 (custom): 8
# ...
# Sum of 1,2,3,4,5: 15
# Factorial of 5: 120
# ...
# Original: [1, 2, 3, 4, 5]
# Squares: [1, 4, 9, 16, 25]
# ...
# Name: Alice, Age: 22, Grade: A
# ...
# greet function doc: None
# calculate_area doc: None
